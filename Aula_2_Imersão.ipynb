# %% [markdown]
# <a href="https://colab.research.google.com/github/emanuellevangista/Processamento-de-Imagens/blob/main/Aula_2_Imers%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geobr -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 28.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 928.1/928.1 KB 61.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 64.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 93.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 KB 11.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires click<8.0,>=5.1, but you have click 8.1.3 which is incompatible.

# %%
# !pip install geopandas==0.12.0 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# geobr 0.2.0 requires geopandas<0.8.0,>=0.7.0, but you have geopandas 0.12.0 which is incompatible.

# %%
import geobr

# %%
geobr.list_geobr()
# Out:
# Function: read_country
# Geographies available: Country
# Years available: 1872, 1900, 1911, 1920, 1933, 1940, 1950, 1960, 1970, 1980, 1991, 2000, 2001, 2010, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020
# Source: IBGE
# ------------------------------
# Function: read_region
# Geographies available: Region
# Years available: 2000, 2001, 2010, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020
# Source: IBGE
# ------------------------------
# Function: read_state
# Geographies available: States
# Years available: 1872, 1900, 1911, 1920, 1933, 1940, 1950, 1960, 1970, 1980, 1991, 2000, 2001, 2010, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020
# Source: IBGE
# ------------------------------
# Function: read_meso_region
# Geographies available: Meso region
# Years available: 2000, 2001, 2010, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020
# Source: IBGE
# ------------------------------
# Function: read_micro_region
# Geographies available: Micro region
# ...

# %%
censo_sp_2010= geobr.read_census_tract(code_tract="SP", year=2010)

# %%
censo_sp_2010.head()
# Out:
#         code_tract    zone  code_muni     name_muni name_neighborhood  \
# 0  354100005000009  URBANO  3541000.0  Praia Grande         Boqueirão
# 1  354100005000004  URBANO  3541000.0  Praia Grande         Boqueirão
# 2  354100005000002  URBANO  3541000.0  Praia Grande         Boqueirão
# 3  354100005000001  URBANO  3541000.0  Praia Grande         Boqueirão
# 4  354100005000003  URBANO  3541000.0  Praia Grande         Boqueirão
#
#    code_neighborhood  code_subdistrict  name_subdistrict  code_district  \
# 0       3.541000e+11      3.541000e+10               NaN    354100005.0
# 1       3.541000e+11      3.541000e+10               NaN    354100005.0
# 2       3.541000e+11      3.541000e+10               NaN    354100005.0
# 3       3.541000e+11      3.541000e+10               NaN    354100005.0
# 4       3.541000e+11      3.541000e+10               NaN    354100005.0
#
#   name_district  code_state                                           geometry
# ...

# %%
censo_sp_2010.plot()

# %%
import pandas as pd

munis= pd.unique(censo_sp_2010.name_muni)

# %%
print(len(munis))
print(munis)
# Out:
# 645
# ['Praia Grande' 'Araçatuba' 'Atibaia' 'Adamantina' 'Adolfo' 'Aguaí'
#  'Águas Da Prata' 'Águas De Lindóia' 'Águas De Santa Bárbara'
#  'Águas De São Pedro' 'Agudos' 'Alambari' 'Alfredo Marcondes' 'Altair'
#  'Altinópolis' 'Alto Alegre' 'Alumínio' 'Álvares Florence'
#  'Álvares Machado' 'Álvaro De Carvalho' 'Alvinlândia' 'Americana'
#  'Américo Brasiliense' 'Américo De Campos' 'Amparo' 'Analândia'
#  'Andradina' 'Angatuba' 'Anhembi' 'Anhumas' 'Aparecida'
#  "Aparecida D'oeste" 'Apiaí' 'Araçariguama' 'Araçoiaba Da Serra' 'Aramina'
#  'Arandu' 'Arapeí' 'Araraquara' 'Araras' 'Arco-Íris' 'Arealva' 'Areias'
#  'Areiópolis' 'Ariranha' 'Artur Nogueira' 'Arujá' 'Aspásia' 'Assis'
#  'Auriflama' 'Avaí' 'Avanhandava' 'Avaré' 'Bady Bassitt' 'Balbinos'
#  'Bálsamo' 'Bananal' 'Barão De Antonina' 'Barbosa' 'Bariri' 'Barra Bonita'
#  'Barra Do Chapéu' 'Barra Do Turvo' 'Barretos' 'Barueri' 'Bauru'
#  'Bento De Abreu' 'Bernardino De Campos' 'Birigui' 'Boituva' 'Barrinha'
# ...

# %%
nomes=[]

for mun in munis:
  if mun.startswith("São"):
   nomes.append(mun)
nomes
# Out:
# ['São Bernardo Do Campo',
#  'São José Do Rio Pardo',
#  'São José Do Rio Preto',
#  'São Bento Do Sapucaí',
#  'São Caetano Do Sul',
#  'São Carlos',
#  'São Francisco',
#  'São João Da Boa Vista',
#  'São João Das Duas Pontes',
#  'São João De Iracema',
#  "São João Do Pau D'alho",
#  'São Joaquim Da Barra',
#  'São José Da Bela Vista',
#  'São José Do Barreiro',
#  'São José Dos Campos',
#  'São Paulo',
#  'São Lourenço Da Serra',
#  'São Luís Do Paraitinga',
#  'São Manuel',
#  'São Miguel Arcanjo',
#  'São Roque',
#  'São Vicente',
#  'São Pedro',
#  'São Pedro Do Turvo',
#  'São Sebastião',
#  'São Sebastião Da Grama',
#  'São Simão']

# %%
censo_sjc_2010=censo_sp_2010[censo_sp_2010["name_muni"]=="São José Dos Campos"]

# %%
censo_sjc_2010.plot()

# %%
urbano= geobr.read_urban_area(year=2015)

# %%
urbano.plot()

# %%
urbano_sjc=urbano[urbano.code_muni==3549904]
urbano_sjc.plot()

# %%
import matplotlib.pyplot as plt

# %%
fig,eixo = plt.subplots(figsize=(10,10))
urbano_sjc.plot(column= urbano_sjc.density, categorical=True, ax=eixo, cmap="RdYlG", plt.legend=True)
# Out:
#   File "<ipython-input-58-01322ea9ba3e>", line 2
#     urbano_sjc.plot(column= urbano_sjc.density, categorical=True, ax=eixo, cmap="RdYlG", plt.legend=True)
#                                                                                          ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
fig,eixo = plt.subplots(figsize=(10,10))
urbano_sjc.plot(column= urbano_sjc.density, categorical=True, ax=eixo, cmap="RdYlG", plt.legend=True)
censo_sjc_2010boun
# Out:
#   File "<ipython-input-51-294f37b0a1c8>", line 2
#     urbano_sjc.plot(column= urbano_sjc.density, categorical=True, ax=eixo, cmap="RdYlG", plt.legend=True)
#                                                                                          ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
# !pip install contextily -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 58.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 KB 6.4 MB/s eta 0:00:00

# %%
import contextily as cx

# %%
fig,eixo = plt.subplots(figsize=(10,10))
urbano_sjc.plot(column= urbano_sjc.density, categorical=True, ax=eixo, cmap="RdYlG", plt.legend=True)
censo_sjc_2010.boundary.plot(ax=eixo)
cx.add_basemap(ax=eixo, crs= urbano_sjc.crs)
# Out:
#   File "<ipython-input-54-e71186ffb828>", line 2
#     urbano_sjc.plot(column= urbano_sjc.density, categorical=True, ax=eixo, cmap="RdYlG", plt.legend=True)
#                                                                                          ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
fig,eixo = plt.subplots(figsize=(10,10))
urbano_sjc.plot(column= urbano_sjc.density, ax=eixo, apha=0.7, color="darkred")
censo_sjc_2010.boundary.plot(ax=eixo, color="black", alpha=0.4)
cx.add_basemap(ax=eixo, crs= urbano_sjc.crs)
# Out:
# /usr/local/lib/python3.8/dist-packages/geopandas/plotting.py:656: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-b9a735b4b5c7> in <module>
#       1 fig,eixo = plt.subplots(figsize=(10,10))
# ----> 2 urbano_sjc.plot(column= urbano_sjc.density, ax=eixo, apha=0.7, color="darkred")
#       3 censo_sjc_2010.boundary.plot(ax=eixo, color="black", alpha=0.4)
#       4 cx.add_basemap(ax=eixo, crs= urbano_sjc.crs)
#
# /usr/local/lib/python3.8/dist-packages/geopandas/plotting.py in __call__(self, *args, **kwargs)
#     966         kind = kwargs.pop("kind", "geo")
#     967         if kind == "geo":
# --> 968             return plot_dataframe(data, *args, **kwargs)
#     969         if kind in self._pandas_kinds:
#     970             # Access pandas plots
#
# ...

# %%
# !pip install matplotlib-scalebar -q

# %%
from matplotlib_scalebar.scalebar

# %%
urbano_sjc.to_crs(epsg=31983)
